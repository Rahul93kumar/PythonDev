# %%
# !pip install pandas

# %% [markdown]
# # Different ways to create pandas DataFrame

# %%
import pandas as pd

# %% [markdown]
# # Creating DF using csv

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1=pd.read_csv(r"E:\Courses\Scodeen Global Videos\ML\ML\Bengaluru_House_Data.csv" )

# %%
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # # Creating DF using Excel

# %%
df2=pd.read_excel("test123.xlsx")

# %%
df2
# Out:
#    Unnamed: 0  id       name     city country
# 0           0  23  fyhvdsjbw  fghbjnk   INDIA
# 1           1  47      sfhgs     cvbn   INDIA
# 2           2  45   fyghbjnk      vhb   INDIA

# %%
# create DF from Dict

# %%
py_dict={
    'name':['copper','silver','iron_ore','alumina'],
    'seg':['a','b','c','d'],
    'price':[345,567,765,987]
}

# %%
df3=pd.DataFrame(py_dict)

# %%
df3
# Out:
#        name seg  price
# 0    copper   a    345
# 1    silver   b    567
# 2  iron_ore   c    765
# 3   alumina   d    987

# %%
# Creating a DF from list of dict

# %%
py=[
    {"id":101,"sales":15243,"temp":38},
    {"id":102,"sales":2523,"temp":39},
    {"id":103,"sales":35243,"temp":40}
]

# %%
df4=pd.DataFrame(py)

# %%
df4
# Out:
#     id  sales  temp
# 0  101  15243    38
# 1  102   2523    39
# 2  103  35243    40

# %%
#  Creating DF from api

# %%
df5=pd.read_json("https://api.sampleapis.com/beers/ale")

# %%
df5
# Out:
#        price                                             name  \
# 0     $16.99                             Founders All Day IPA
# 1     $13.99  Blue Moon Belgian White Belgian-Style Wheat Ale
# 2     $16.99                             Guinness Extra Stout
# 3      $8.99                             Guinness Extra Stout
# 4     $15.49                           Sierra Nevada Pale Ale
# ..       ...                                              ...
# 184  $999.99                                      Bazooka 999
# 185  $999.99                                      Bazooka 999
# 186  $999.99                                      Bazooka 999
# 187  $999.99                                      Bazooka 999
# 188  $999.99                                      Bazooka 999
#
#                                               rating  \
# 0     {'average': 4.411243509154233, 'reviews': 453}
# 1    {'average': 4.7752608333834825, 'reviews': 305}
# 2     {'average': 3.978596147459463, 'reviews': 119}
# ...

# %%
# creating DF from html

# %%
df6=pd.read_html("https://www.espncricinfo.com/")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 df6=pd.read_html("https://www.espncricinfo.com/")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
# ...

# %%
# !pip install html5lib

# %%
df6=pd.read_html("https://www.espncricinfo.com/")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 df6=pd.read_html("https://www.espncricinfo.com/")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
# ...

# %%
# !pip install html5lib

# %%
df6=pd.read_html('https://www.worldometers.info/coronavirus/')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 df6=pd.read_html('https://www.worldometers.info/coronavirus/')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
# ...

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install beautifulsoup4

# %%
df6=pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory')

# %%
df6[0]
# Out:
#                                     COVID-19 pandemic  \
# 0   Confirmed deaths per 100,000 population,[1][no...
# 1                                             Disease
# 2                                        Virus strain
# 3                                              Source
# 4                                            Location
# 5                                      First outbreak
# 6                                          Index case
# 7                                                Date
# 8                                     Confirmed cases
# 9                                              Deaths
# 10                                       Vaccinations
#
#                                   COVID-19 pandemic.1
# 0   Confirmed deaths per 100,000 population,[1][no...
# 1                                            COVID-19
# 2                                          SARS-CoV-2
# 3         Probably bats, possibly via pangolins[2][3]
# ...

# %%
df6[1]
# Out:
#                                                    0
# 0  Map of total confirmed cases by country[9][not...
# 1        Date of latest upload at the Commons source

# %%
df6[2]
# Out:
#                                                    0
# 0  Map of confirmed cases per million by country[...
# 1        Date of latest upload at the Commons source

# %%
df6[5]
# Out:
#                                                    0
# 0  Map of daily new confirmed deaths per million ...
# 1                                       Date on map.

# %%
df6[12]
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
# 220  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                               Bosnia and Herzegovina
# ...

# %%
type(df6)
# Out:
# list
